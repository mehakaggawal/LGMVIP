# %% [markdown]
# # **LetsGrowMore**
# ## **Data Science Intern**
# ### Task 4: Image to Pencil Sketch with Python
# ### Author: Mehak Singhal

# %% [markdown]
# ![Task4.png](data:image/png;base64,...)

# %% [markdown]
#  # Importing required libraries

# %%
from google.colab.patches import cv2_imshow
import cv2

# %% [markdown]
# # Loading the image

# %%
img = cv2.imread('dog.jpg', 1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x480 at 0x7FD2245D54D0>

# %% [markdown]
# # Converting an image into gray_scale image

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x480 at 0x7FD21244DB50>

# %% [markdown]
# Converting an image into grayscale gives us black & white pixels in the image which is used for creating a pencil sketch.

# %% [markdown]
# # Inverting the image

# %%
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FD212454550>

# %% [markdown]
# By using this function, it is dividing the greyscale value of the image by the inverse of blurred image value which highlights the boldest edges.

# %% [markdown]
# # Smoothing the image

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FD2124610D0>

# %% [markdown]
# We have used the gaussian blur technique with 21 x 21 pixel and the default sigma values filter on the image to smoothen our image. By increasing the filter size, we can create thin lines for our sketch and it is used to reduce the noise in the image.

# %% [markdown]
# # Obtaining the final sketch

# %%
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %% [markdown]
# By using this function, it is dividing the greyscale value of the image by the inverse of blurred image value which highlights the boldest edges.

# %% [markdown]
# # Final Output as Pencil Sketch

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FD2212437D0>
